# %% [markdown]
# # Table of Contents
# 1. [Introduction](#intro)
# 2. [Project Overview](#project-overview)
#     - [Key Features](#key-features)
#     - [Plot](#plot)
# 3. [Data Visualization](#data-visualization)
# 4. [Conclusion](#conclusion)
# 5. [Commit History Reflection](#commit-history)

# %% [markdown]
# <a class="anchor" id="intro"></a>
# # Introduction
#
# In this notebook, we explore an interesting GitHub project. The project is titled **Candy Power Ranking**, and it contains the data behind 538's story of The Ultimate Halloween Candy Power Ranking.
#
#
# 🔗 [Candy Power Ranking](https://github.com/fivethirtyeight/data/tree/master/candy-power-ranking)

# %% [markdown]
# <a class="anchor" id="project-overview"></a>
# # Project Overview
#
# This project is designed to:
#
# - Provide data for replication analysis and for potential extensions
#
# <a class="anchor" id="key-features"></a>
# ## Key Features
#
# - **Cleaned Data**: The data provided in the csv file has been fully cleaned and is ready for analysis
#
# <a class="anchor" id="plot"></a>
# ## Plot
#
# I plotted a **regression of win percentage on sugar percentage**.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# Load the data
file_path = "https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv"
df = pd.read_csv(file_path)

# Select relevant columns
x_col = "sugarpercent"
y_col = "winpercent"

# Drop missing values if any
df = df[[x_col, y_col]].dropna()

# Perform linear regression
X = sm.add_constant(df[x_col])  # Add constant for intercept
model = sm.OLS(df[y_col], X).fit()

# Plot the regression
plt.figure(figsize=(8, 5))
sns.regplot(x=df[x_col], y=df[y_col], ci=None, line_kws={"color": "red"})
plt.xlabel("Sugar Percentage")
plt.ylabel("Win Percentage")
plt.title("Regression of Win Percentage on Sugar Percentage")

# Show plot
plt.show()

# Display regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             winpercent   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     4.600
# Date:                Mon, 10 Feb 2025   Prob (F-statistic):             0.0349
# Time:                        17:02:21   Log-Likelihood:                -346.36
# No. Observations:                  85   AIC:                             696.7
# Df Residuals:                      83   BIC:                             701.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           44.6094      3.086     14.455      0.000      38.471      50.748
# ...

# %% [markdown]
# <a class="anchor" id="conclusion"></a>
# # Conclusion
#
# This project provides a cleaned dataset behind their piece on candy popularity.

# %% [markdown]
# <a class="anchor" id="commit-history"></a>
# # Commit History Reflection
#
# When reviewing the commit history, I noticed that Jupyter Notebook files are stored in JSON format, making them harder to read in the commit log. However, the Python script appeared in a familiar format because it is plain text.
